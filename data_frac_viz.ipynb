# %%
from pathlib import Path
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
# libraries
from pandas.plotting import parallel_coordinates

# %%
from pathlib import Path

# %%
data_dir = Path("data_frac")
file_to_open = data_dir / "data_frac.json"

# %%
# read the data
df = pd.read_json(file_to_open)

# %%
df
# Out:
#      Test  Q (GPM)  Test T (°F)  Qin (GPM)  QL-out (GPM)  Tin (°F)  Tout (°F)
# 0       2        2           75       1.94          2.52     76.38      74.16  \
# 1   3 (1)        3           77       2.91          2.48     79.46      77.31
# 2   3 (2)        3           77       2.90          2.48     84.46      82.72
# 3   4 (1)        4           77       4.18          3.99     79.11      76.89
# 4   4 (2)        4           77       4.05          3.71     84.89      83.35
# 5   4 (3)        4          194       3.99          3.76     83.36     108.55
# 6   4 (4)        4          194       3.22          2.47     76.40     107.85
# 7   4 (5)        4          302       2.76          3.85     76.40     149.01
# 8   6 (1)        6           77       5.92          4.57     82.70      81.16
# 9   6 (2)        6           77       5.81          2.48     79.46      77.31
# 10  6 (3)        6          194       5.40          4.88    101.97     110.03
# 11  6 (4)        6          194       3.65          4.98     81.11     102.31
# 12  8 (1)        8           77       8.44          6.06     83.67      81.86
# 13  8 (2)        8          194       8.52          5.59     90.86      95.63
# 14     12       12           77      12.36          7.93     82.43      80.62
# 15     10       10           77      10.48          6.73     76.64      74.40
# 16     15       15           77      13.86          8.18     77.63      75.64
#
#     Pin (Psi)  Pout (Psi)
# 0       15.60       14.15
# 1       16.51       14.61
# 2       16.72       14.93
# 3       20.06       17.02
# 4       18.94       16.28
# 5       18.54       15.80
# 6       16.10       14.00
# 7       17.86       14.65
# 8       25.21       20.51
# 9       16.51       14.61
# 10      25.99       20.47
# 11      26.20       20.57
# 12      36.80       27.50
# 13      34.70       26.72
# 14      60.71       41.91
# 15      47.11       34.32
# 16      69.51       47.98

# %%
# Make the plot
fig = plt.figure()
# set fig size
fig.set_size_inches(12, 5)
parallel_coordinates(df, 'Test', colormap=plt.get_cmap("Set2"))
plt.show()
