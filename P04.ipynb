# %%
import matplotlib.pyplot as plt

# Data
data = [
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 74, "n": 0.972, "K": 3.848, "r2": 1},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 120, "n": 0.952, "K": 0.943, "r2": 1},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 220, "n": 0.262, "K": 4.34, "r2": 0.94},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 310, "n": 0.059, "K": 7.668, "r2": 0.85},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 410, "n": 0, "K": 9.186, "r2": 0.01},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Temperature (F)": 480, "n": 0.038, "K": 7.623, "r2": 0.69},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 74, "n": 0.981, "K": 7.631, "r2": 1},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 120, "n": 0.799, "K": 5.497, "r2": 1},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 220, "n": 0.109, "K": 18.798, "r2": 0.78},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 310, "n": 0.027, "K": 17.406, "r2": 0.74},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 410, "n": -0.031, "K": 18.875, "r2": 0.76},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Temperature (F)": 480, "n": 0.063, "K": 8.866, "r2": 0.92},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 74, "n": 1.037, "K": 9.036, "r2": 1},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 120, "n": 1.012, "K": 2.902, "r2": 1},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 220, "n": 0.133, "K": 18.339, "r2": 0.8},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 310, "n": 0.016, "K": 21.746, "r2": 0.52},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 410, "n": -0.003, "K": 21.982, "r2": 0.78},
    {"Ionic Liquid": "1-Octylpyridinium bromide (OPyBr)", "Temperature (F)": 480, "n": 0, "K": 21.734, "r2": 0},
]

# Extracting unique ionic liquid names
ionic_liquids = list(set(item["Ionic Liquid"] for item in data))

# Creating a dictionary to store n values for each ionic liquid
n_values = {ionic_liquid: [] for ionic_liquid in ionic_liquids}

# Populating the n_values dictionary
for item in data:
    ionic_liquid = item["Ionic Liquid"]
    n_value = item["n"]
    n_values[ionic_liquid].append(n_value)

plt.figure(figsize=(12, 8))
font_size = 25
plt.rcParams.update({"font.size": font_size})
#legend size
plt.rcParams["legend.fontsize"] = font_size - 5

# Plotting n versus temperature for each ionic liquid
for ionic_liquid in ionic_liquids:
    temperatures = [item["Temperature (F)"] for item in data if item["Ionic Liquid"] == ionic_liquid]
    n_values_i = n_values[ionic_liquid]

    plt.plot(temperatures, n_values_i, marker='o', label=ionic_liquid)



# Set plot title and labels
plt.title("n versus Temperature for Different Ionic Liquids")
plt.xlabel("Temperature (F)")
plt.ylabel("n")

# change the figure background color
plt.gca().set_facecolor("w")
# font size
plt.rcParams.update({"font.size": font_size})
# Add legend
plt.legend()
# make grid
# make small grid
plt.grid(True, which="both", ls="--", color="0.65")


# Display the plot
plt.show()

# %%
# Extracting unique ionic liquid names
ionic_liquids = list(set(item["Ionic Liquid"] for item in data))

# Creating a dictionary to store K values for each ionic liquid
K_values = {ionic_liquid: [] for ionic_liquid in ionic_liquids}
plt.figure(figsize=(12, 8))
font_size = 25
# Populating the K_values dictionary
for item in data:
    ionic_liquid = item["Ionic Liquid"]
    K_value = item["K"]
    K_values[ionic_liquid].append(K_value)

plt.rcParams.update({"font.size": font_size})
#legend size
plt.rcParams["legend.fontsize"] = font_size - 5
# change the figure background color
plt.gca().set_facecolor("w")
# Plotting K versus temperature for each ionic liquid
for ionic_liquid in ionic_liquids:
    temperatures = [item["Temperature (F)"] for item in data if item["Ionic Liquid"] == ionic_liquid]
    K_values_i = K_values[ionic_liquid]

    plt.plot(temperatures, K_values_i, marker='o', label=ionic_liquid)

# Set plot title and labels
plt.title("K versus Temperature for Different Ionic Liquids")
plt.xlabel("Temperature (F)")
plt.ylabel("K")

# make grid
# make small grid
plt.grid(True, which="both", ls="--", color="0.65")

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
data = [
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 100, "n": 0.382, "K": 0.137, "r2": 0.33},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 500, "n": 0.255, "K": 0.406, "r2": 0.47},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 800, "n": 0.208, "K": 0.497, "r2": 0.47},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 1300, "n": 0.306, "K": 0.377, "r2": 0.98},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 1800, "n": 0.291, "K": 0.418, "r2": 0.93},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 100, "n": 0.661, "K": 0.067, "r2": 0.93},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 500, "n": 0.341, "K": 0.295, "r2": 0.77},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 800, "n": 0.429, "K": 0.23, "r2": 0.83},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 1300, "n": 0.435, "K": 0.242, "r2": 0.92},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 1800, "n": 0.203, "K": 0.718, "r2": 0.41},
]

# Extracting unique ionic liquid names
ionic_liquids = list(set(item["Ionic Liquid"] for item in data))

# Creating a dictionary to store 'n' values for each ionic liquid
n_values = {ionic_liquid: [] for ionic_liquid in ionic_liquids}

# Populating the n_values dictionary
for item in data:
    ionic_liquid = item["Ionic Liquid"]
    n_value = item["n"]
    n_values[ionic_liquid].append(n_value)

plt.figure(figsize=(12, 8))
font_size = 25
# change the figure background color
plt.gca().set_facecolor("w")
plt.rcParams.update({"font.size": font_size})
#legend size
plt.rcParams["legend.fontsize"] = font_size - 5
# Plotting 'n' versus pressure for each ionic liquid
for ionic_liquid in ionic_liquids:
    pressures = [item["Pressure (psi)"] for item in data if item["Ionic Liquid"] == ionic_liquid]
    n_values_i = n_values[ionic_liquid]

    plt.plot(pressures, n_values_i, marker='o', label=ionic_liquid)

# Set plot title and labels
plt.title("n versus Pressure for Different Ionic Liquids")
plt.xlabel("Pressure (psi)")
plt.ylabel("n")
# make grid
# make small grid
plt.grid(True, which="both", ls="--", color="0.65")
# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
data = [
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 100, "n": 0.382, "K": 0.137, "r2": 0.33},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 500, "n": 0.255, "K": 0.406, "r2": 0.47},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 800, "n": 0.208, "K": 0.497, "r2": 0.47},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 1300, "n": 0.306, "K": 0.377, "r2": 0.98},
    {"Ionic Liquid": "1-Hexylpyridinium tetrafluoroborate (HPyBF4)", "Pressure (psi)": 1800, "n": 0.291, "K": 0.418, "r2": 0.93},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 100, "n": 0.661, "K": 0.067, "r2": 0.93},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 500, "n": 0.341, "K": 0.295, "r2": 0.77},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 800, "n": 0.429, "K": 0.23, "r2": 0.83},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 1300, "n": 0.435, "K": 0.242, "r2": 0.92},
    {"Ionic Liquid": "N-Hexylpyridinium bromide (HPyBr)", "Pressure (psi)": 1800, "n": 0.203, "K": 0.718, "r2": 0.41},
]

# Extracting unique ionic liquid names
ionic_liquids = list(set(item["Ionic Liquid"] for item in data))

# Creating a dictionary to store 'K' values for each ionic liquid
K_values = {ionic_liquid: [] for ionic_liquid in ionic_liquids}

# Populating the K_values dictionary
for item in data:
    ionic_liquid = item["Ionic Liquid"]
    K_value = item["K"]
    K_values[ionic_liquid].append(K_value)


plt.figure(figsize=(12, 8))
font_size = 25
# change the figure background color
plt.gca().set_facecolor("w")
plt.rcParams.update({"font.size": font_size})
#legend size
plt.rcParams["legend.fontsize"] = font_size - 5
# Plotting 'K' versus pressure for each ionic liquid
for ionic_liquid in ionic_liquids:
    pressures = [item["Pressure (psi)"] for item in data if item["Ionic Liquid"] == ionic_liquid]
    K_values_i = K_values[ionic_liquid]
    plt.plot(pressures, K_values_i, marker='o', label=ionic_liquid)

# Set plot title and labels
plt.title("K versus Pressure for Different Ionic Liquids")
plt.xlabel("Pressure (psi)")
plt.ylabel("K")

# Add legend
plt.legend()
# make small grid
plt.grid(True, which="both", ls="--", color="0.65")
# Display the plot
plt.show()
