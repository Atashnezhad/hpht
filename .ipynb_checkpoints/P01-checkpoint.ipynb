# %%
import pandas as pd
from pathlib import Path
import os

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from typing import List, Dict


class ProcessData:

       def __init__(self, *args, **kwargs):
              self.data_folder_address = Path("__file__").parent / "data" or kwargs.get("data_folder_address")
              self.keep_cols = kwargs.get("keep_cols")

       @property
       def data_file_list(self):
              _list = [file for file in os.listdir(self.data_folder_address)]
              return _list

       def read_data(self, file_name):
              address = self.data_folder_address / file_name
              df = pd.read_csv(address, encoding= 'unicode_escape')
              return df

       def rename_columns(self, df):

              column_list = df.columns.tolist()
              first_row = df.iloc[0].tolist()
              new_column_list = [str(i) + "_" + str(j) for i, j in zip(column_list, first_row)]
              df = df.drop([0])
              df.columns = new_column_list
              return df

       def make_float(self, df, except_cols:List[str] = None):
              if not except_cols:
                     df = df.astype(float)
                     return df
              for col in df.columns:
                  if col not in except_cols:
                         df[col] = df[col].astype(float)
              return df

       def keep_columns(self, df, keep_cols=None):
              if keep_cols:
                     df = df[keep_cols]
                     return df
              else:
                     keep_cols = [
                     'Sample Temp_(°F)', 'Pressure_(PSIg)', 'Rotor Speed_(RPM)',
                            'Shear Rate_(1/s)','Shear Stress_(dyne/cm²)',
                            'Viscosity_(cP)','Bob Deflection_(deg.)',
                            'Torque_(dyne-cm)', 'Raw Encoder Value_(cts)'
                     ]
                     df = df[keep_cols]
                     return df

       def plot_heatmap(self, df, title='Correlation Heatmap'):
              plt.figure(figsize=(10,8))
              sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
              # add title
              plt.title(title, fontsize=20)
              plt.show()

       def plot_pairplot(self, df):
              plt.figure(figsize=(10,8))
              sns.pairplot(df, height=2)
              plt.show()

       def print_corr_with_resp(self, df, resp_col="Viscosity_(cP)"):
              corr  = df.corr()[resp_col].sort_values(ascending=False)
              print(corr)

       def concate_data(self, dataframes:Dict[str, pd.DataFrame] = None) -> pd.DataFrame:

              dataframe_list = []
              for key, df in dataframes.items():
                  df["dataframe_name"] = key
                  dataframe_list.append(df)

              # concatenate all dataframes
              df = pd.concat(dataframe_list, ignore_index=True)
              return df

# %%
obj = ProcessData()
# obj.data_file_list
df = obj.read_data("opybr-AA-cons-T.csv")
df = obj.rename_columns(df)
df = obj.make_float(df)
df = obj.keep_columns(df)
obj.plot_heatmap(df, title="OPyBr-cons-T")
# obj.plot_pairplot(df)
obj.print_corr_with_resp(df)
# Out:
# Viscosity_(cP)             1.000000
# Torque_(dyne-cm)           0.988583
# Shear Stress_(dyne/cm²)    0.988583
# Raw Encoder Value_(cts)    0.988576
# Bob Deflection_(deg.)      0.988576
# Rotor Speed_(RPM)         -0.164427
# Shear Rate_(1/s)          -0.164430
# Pressure_(PSIg)           -0.207077
# Sample Temp_(°F)          -0.571355
# Name: Viscosity_(cP), dtype: float64

# %%
obj = ProcessData()
# obj.data_file_list
df = obj.read_data("hpybr-AA-cons-T.csv")
df = obj.rename_columns(df)
df = obj.make_float(df)
df = obj.keep_columns(df)
obj.plot_heatmap(df, title="HPyBr-cons-T")
# obj.plot_pairplot(df)
obj.print_corr_with_resp(df)
# Out:
# Viscosity_(cP)             1.000000
# Shear Stress_(dyne/cm²)    0.898362
# Torque_(dyne-cm)           0.898359
# Bob Deflection_(deg.)      0.898117
# Raw Encoder Value_(cts)    0.898117
# Pressure_(PSIg)           -0.037985
# Rotor Speed_(RPM)         -0.258415
# Shear Rate_(1/s)          -0.258419
# Sample Temp_(°F)          -0.552420
# Name: Viscosity_(cP), dtype: float64

# %%
obj = ProcessData()
# obj.data_file_list
df = obj.read_data("hpybr-AA-cons-T.csv")
df = obj.rename_columns(df)
df = obj.make_float(df)
df = obj.keep_columns(df)
df1 = df

obj = ProcessData()
# obj.data_file_list
df = obj.read_data("opybr-AA-cons-P.csv")
df = obj.rename_columns(df)
df = obj.make_float(df)
df = obj.keep_columns(df)
df2 = df

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2913 entries, 1 to 2913
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample Temp_(°F)         2913 non-null   float64
#  1   Pressure_(PSIg)          2913 non-null   float64
#  2   Rotor Speed_(RPM)        2913 non-null   float64
#  3   Shear Rate_(1/s)         2913 non-null   float64
#  4   Shear Stress_(dyne/cm²)  2913 non-null   float64
#  5   Viscosity_(cP)           2913 non-null   float64
#  6   Bob Deflection_(deg.)    2913 non-null   float64
#  7   Torque_(dyne-cm)         2913 non-null   float64
#  8   Raw Encoder Value_(cts)  2913 non-null   float64
# dtypes: float64(9)
# memory usage: 204.9 KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4962 entries, 1 to 4962
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample Temp_(°F)         4962 non-null   float64
#  1   Pressure_(PSIg)          4962 non-null   float64
#  2   Rotor Speed_(RPM)        4962 non-null   float64
#  3   Shear Rate_(1/s)         4962 non-null   float64
#  4   Shear Stress_(dyne/cm²)  4962 non-null   float64
#  5   Viscosity_(cP)           4962 non-null   float64
#  6   Bob Deflection_(deg.)    4962 non-null   float64
#  7   Torque_(dyne-cm)         4962 non-null   float64
#  8   Raw Encoder Value_(cts)  4962 non-null   float64
# dtypes: float64(9)
# memory usage: 349.0 KB

# %%
obj.data_file_list
# Out:
# ['hpybf4-AA-cons-P-2.csv',
#  'hpybf4-AA-cons-P.csv',
#  'hpybf4-AA-cons-T.csv',
#  'hpybr-AA-cons-T.csv',
#  'opybr-AA-cons-P-2.csv',
#  'opybr-AA-cons-P.csv',
#  'opybr-AA-cons-T.csv']

# %%
dataframes = {}
for file in obj.data_file_list:
       obj = ProcessData()
       # obj.data_file_list
       df = obj.read_data(file)
       df = obj.rename_columns(df)
       # df = obj.make_float(df)
       df = obj.keep_columns(df)
       df = obj.make_float(df)
       dataframes[file] = df

# %%
dataframes.get("hpybr-AA-cons-T.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2913 entries, 1 to 2913
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample Temp_(°F)         2913 non-null   float64
#  1   Pressure_(PSIg)          2913 non-null   float64
#  2   Rotor Speed_(RPM)        2913 non-null   float64
#  3   Shear Rate_(1/s)         2913 non-null   float64
#  4   Shear Stress_(dyne/cm²)  2913 non-null   float64
#  5   Viscosity_(cP)           2913 non-null   float64
#  6   Bob Deflection_(deg.)    2913 non-null   float64
#  7   Torque_(dyne-cm)         2913 non-null   float64
#  8   Raw Encoder Value_(cts)  2913 non-null   float64
# dtypes: float64(9)
# memory usage: 204.9 KB

# %%
final_df = obj.concate_data(dataframes)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27341 entries, 0 to 27340
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample Temp_(°F)         27341 non-null  float64
#  1   Pressure_(PSIg)          27341 non-null  float64
#  2   Rotor Speed_(RPM)        27341 non-null  float64
#  3   Shear Rate_(1/s)         27341 non-null  float64
#  4   Shear Stress_(dyne/cm²)  27341 non-null  float64
#  5   Viscosity_(cP)           27341 non-null  float64
#  6   Bob Deflection_(deg.)    27341 non-null  float64
#  7   Torque_(dyne-cm)         27341 non-null  float64
#  8   Raw Encoder Value_(cts)  27341 non-null  float64
#  9   dataframe_name           27341 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 2.1+ MB

# %%
final_df.columns
# Out:
# Index(['Sample Temp_(°F)', 'Pressure_(PSIg)', 'Rotor Speed_(RPM)',
#        'Shear Rate_(1/s)', 'Shear Stress_(dyne/cm²)', 'Viscosity_(cP)',
#        'Bob Deflection_(deg.)', 'Torque_(dyne-cm)', 'Raw Encoder Value_(cts)',
#        'dataframe_name'],
#       dtype='object')

# %%
df = final_df[['Sample Temp_(°F)', 'Pressure_(PSIg)', 'Rotor Speed_(RPM)',
       'Shear Rate_(1/s)', 'Shear Stress_(dyne/cm²)', 'Viscosity_(cP)',
       'Bob Deflection_(deg.)', 'Torque_(dyne-cm)', 'Raw Encoder Value_(cts)']]

obj.plot_heatmap(df, title="All Data")

# %%
obj.print_corr_with_resp(df)
# Out:
# Viscosity_(cP)             1.000000
# Shear Stress_(dyne/cm²)    0.985340
# Torque_(dyne-cm)           0.985340
# Bob Deflection_(deg.)      0.985020
# Raw Encoder Value_(cts)   -0.016844
# Rotor Speed_(RPM)         -0.031066
# Shear Rate_(1/s)          -0.031067
# Pressure_(PSIg)           -0.069133
# Sample Temp_(°F)          -0.480223
# Name: Viscosity_(cP), dtype: float64
